# %% [markdown]
# # JPL Small-Body Database (SBDB)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sbdb_query_results.csv')
df.head()
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_25180\222306952.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('sbdb_query_results.csv')
#                   full_name         a         e          i          om  \
# 0         1 Ceres (A801 AA)  2.767254  0.078913  10.586880   80.254978
# 1        2 Pallas (A802 FA)  2.770127  0.230229  34.925835  172.918806
# 2          3 Juno (A804 RA)  2.669263  0.256213  12.990552  169.839167
# 3         4 Vesta (A807 FA)  2.361922  0.089449   7.142177  103.709992
# 4       5 Astraea (A845 XA)  2.576886  0.187439   5.358657  141.468997
#
#             w         q        ad     per_y  data_arc condition_code  \
# 0   73.421797  2.548883  2.985625  4.603433    9520.0              0
# 1  310.872894  2.132363  3.407892  4.610604   79903.0              0
# 2  247.737938  1.985362  3.353164  4.361092   79739.0              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1327782 entries, 0 to 1327781
# Data columns (total 15 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   full_name       1327782 non-null  object
#  1   a               1326018 non-null  float64
#  2   e               1327782 non-null  float64
#  3   i               1327782 non-null  float64
#  4   om              1327782 non-null  float64
#  5   w               1327782 non-null  float64
#  6   q               1327782 non-null  float64
#  7   ad              1325542 non-null  float64
#  8   per_y           1325483 non-null  float64
#  9   data_arc        1324932 non-null  float64
#  10  condition_code  1324905 non-null  object
#  11  n_obs_used      1327711 non-null  float64
#  12  n_del_obs_used  1026 non-null     float64
#  13  n_dop_obs_used  1026 non-null     float64
#  14  H               1322703 non-null  float64
# dtypes: float64(13), object(2)
# ...

# %%
df.describe()
# Out:
#                   a             e             i            om             w  \
# count  1.326018e+06  1.327782e+06  1.327782e+06  1.327782e+06  1.327782e+06
# mean  -3.267978e+05  1.602826e-01  9.506557e+00  1.691780e+02  1.815973e+02
# std    3.763160e+08  1.021983e-01  8.499822e+00  1.030056e+02  1.037715e+02
# min   -4.333386e+11  0.000000e+00  6.071324e-03  0.000000e+00  5.878147e-06
# 25%    2.396098e+00  9.323103e-02  4.366367e+00  8.117829e+01  9.149355e+01
# 50%    2.661593e+00  1.474905e-01  7.830916e+00  1.603971e+02  1.831872e+02
# 75%    3.020911e+00  2.039893e-01  1.268568e+01  2.543493e+02  2.714523e+02
# max    1.619082e+06  3.356215e+00  1.792123e+02  3.599997e+02  3.599998e+02
#
#                   q            ad         per_y      data_arc    n_obs_used  \
# count  1.327782e+06  1.325542e+06  1.325483e+06  1.324932e+06  1.327711e+06
# mean   2.390843e+00  1.679997e+01  4.391846e+03  6.141891e+03  3.018521e+02
# ...

# %%
# count nulls
df.isnull().sum()
# Out:
# full_name               0
# a                    1764
# e                       0
# i                       0
# om                      0
# w                       0
# q                       0
# ad                   2240
# per_y                2299
# data_arc             2850
# condition_code       2877
# n_obs_used             71
# n_del_obs_used    1326756
# n_dop_obs_used    1326756
# H                    5079
# dtype: int64

# %%
# plot a histogram of the semi major axis for values of H between 1.5 and 6
df['a'].hist(bins=10000, range=(1.5, 6))
# Out:
# <Axes: >

# %%
# plot a histogram of the absolute magnitude
df.hist(column='H', bins=1000)
# Out:
# array([[<Axes: title={'center': 'H'}>]], dtype=object)
